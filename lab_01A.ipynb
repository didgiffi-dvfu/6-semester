# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

# %% [markdown]
# # Что такое линейна регрессия
# Линейная регрессия — это способ: предсказывать число (например, цену, рост, время)  на основе других числовых признаков
# x — это данные (признаки)
# theta — это важность каждого признака

# %%
def linear_func(theta: np.ndarray, x: np.ndarray) -> float:
    """Computes linear regression value for sample x.
    Arguments:
        theta: 1d array of float, regression coefficients
        x: 1d array of float, sample to compute value for
    Returns:
        float, linear regression value
    """
    # ~ x * ø просто крч считает скалярное произведение 
    return float(np.dot(theta, x))

# %% [markdown]
# Теперь объектов много.
# X — это матрица, где:
# каждая строка — отдельный объект,
# каждый столбец — отдельный признак.
# Если X размера (m, n), то:
# m — число объектов,
# n — число признаков.
# Нужно для каждой строки посчитать скалярное произведение с theta.
#
# Если X — матрица, а theta — вектор, то все предсказания сразу:
#
# Xθ

# %%
def linear_func_all(theta: np.ndarray, X: np.ndarray) -> np.ndarray:
    """Computes linear regression value for all samples in matrix X.
    
    Arguments:
        theta: 1d array of float, regression coefficients
        X: 2d array of float, row-major matrix of samples
        
    Returns:
        1d array of float, linear regression values for all samples in matrix X
    """
    # return float(np.dot(X, theta))
    return X @ theta

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def mean_squared_error(theta: np.ndarray, X: np.ndarray, y: np.ndarray) -> float:
    """Computes MSE loss for linear regression with parameters `theta`
    on samples `X` and true values `y`.
    
    Arguments:
        theta: 1d array of float, regression coefficients
        X: 2d array of float, row-major matrix of samples
        y: 1d array of float, true values
        
    Returns:
        float, mse loss value
    """

    return float( np.mean(( X @ theta) - y)**2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def grad_mean_squared_error(theta: np.ndarray, X: np.ndarray, y: np.ndarray) -> np.ndarray:
    """Computes gradient of mse loss for logistic regression
    with parameters `theta` on samples `X` and true values `y`.
    
    Arguments:
        theta: 1d array of float, regresion coefficients
        X: 2d array of float, row-major matrix of samples
        y: 1d array of int, true values
        
    Returns:
        1d array of float, mse gradient with respect to `theta`
    """
    n = X.shape[0]
    
    return (2 / n) * (X.T @ ((X @ theta) - y))

# %%
import numpy as np
def linear_func(theta: np.ndarray, x: np.ndarray) -> float:
    """Computes linear regression value for sample x.
    Arguments:
        theta: 1d array of float, regression coefficients
        x: 1d array of float, sample to compute value for
    Returns:
        float, linear regression value
    """
    # ~ x * ø просто крч считает скалярное произведение 
    return float(np.dot(theta, x))
    

def linear_func_all(theta: np.ndarray, X: np.ndarray) -> np.ndarray:
    """Computes linear regression value for all samples in matrix X.
    
    Arguments:
        theta: 1d array of float, regression coefficients
        X: 2d array of float, row-major matrix of samples
        
    Returns:
        1d array of float, linear regression values for all samples in matrix X
    """
    # return float(np.dot(X, theta))
    return X @ theta 
    
def mean_squared_error(theta: np.ndarray, X: np.ndarray, y: np.ndarray) -> float:
    """Computes MSE loss for linear regression with parameters `theta`
    on samples `X` and true values `y`.
    
    Arguments:
        theta: 1d array of float, regression coefficients
        X: 2d array of float, row-major matrix of samples
        y: 1d array of float, true values
        
    Returns:
        float, mse loss value
    """

    return float(np.mean(((X @ theta) - y)**2))
    
def grad_mean_squared_error(theta: np.ndarray, X: np.ndarray, y: np.ndarray) -> np.ndarray:
    """Computes gradient of mse loss for logistic regression
    with parameters `theta` on samples `X` and true values `y`.
    
    Arguments:
        theta: 1d array of float, regresion coefficients
        X: 2d array of float, row-major matrix of samples
        y: 1d array of int, true values
        
    Returns:
        1d array of float, mse gradient with respect to `theta`
    """
    n = X.shape[0]
    
    return (2 / n) * (X.T @ ((X @ theta) - y))
